# %%
ls=[1,2,3,4]

# %%
list()
# Out:
# []

# %%
ls
# Out:
# [1, 2, 3, 4]

# %%
ls[1]="hello"
ls
# Out:
# [1, 'hello', 3, 4]

# %%
ls.extend([5,6])
ls
# Out:
# [1, 'hello', 3, 4, 5, 6]

# %%
ls.append([7,8])
ls
# Out:
# [1, 'hello', 3, 4, 5, 6, [7, 8]]

# %%
ls=[1,2,3,4]
ls.insert(2, 5)
ls
# Out:
# [1, 2, 5, 3, 4]

# %%
ls=[3,3,4,5,1,2]
ls
# Out:
# [3, 3, 4, 5, 1, 2]

# %%
ls.count(3)
# Out:
# 2

# %%
ls.sort(reverse=True)
ls
# Out:
# [5, 4, 3, 3, 2, 1]

# %%
ls.sort()
ls
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
#tuple
t=(1,2,3)
type(t)
# Out:
# tuple

# %%
tuple()
# Out:
# ()

# %%
t[1]
# Out:
# 2

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
person={1:1,1:1}
person
# Out:
# {1: 1}

# %%
type(person)
# Out:
# dict

# %%
dict()
# Out:
# {}

# %%
person[1]
# Out:
# 1

# %%
person[1]=100

# %%
person[1]
# Out:
# 100

# %%
d={'a':1,'b':2,'c':3}
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d.get('b')
# Out:
# 2

# %%
d.get('bbb')

# %%
d.get('bbb', 'value not present')
# Out:
# 'value not present'

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
d.pop('a')
# Out:
# 1

# %%
#we can have tuples, string or sigle value but not list as it is unhasbale or mutable
d1={'a':1,'b':2,'c':3, (1,2,3):'hello'}
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3, (1, 2, 3): 'hello'}

# %%
#set
s1=set()
type(s1)
# Out:
# set

# %%
s1.add(2)
s1.add(3)

# %%
s1
# Out:
# {2, 3}

# %%
s2={10,20,3,4,5,1,0}
s2
# Out:
# {0, 1, 3, 4, 5, 10, 20}

# %%
s2={10,'a',10.0,5,6,7}
s2
# Out:
# {10, 5, 6, 7, 'a'}

# %%
s2=s1.copy()
s2
# Out:
# {2, 3}

# %%
s2.pop()
s2
# Out:
# {3}

# %%
s2.add(5)
s2
# Out:
# {3, 5}

# %%
s2.remove(5)
s2
# Out:
# {3}

# %%
s2.add(6)
s2
# Out:
# {3, 6}

# %%
s2.discard(6)
s2
# Out:
# {3}

# %%
2 and 3
# Out:
# 3

# %%
3 and 2
# Out:
# 2

# %%
0 and 3
# Out:
# 0

# %%
3 and 0
# Out:
# 0

# %%
0 or 3
# Out:
# 3

# %%
3 or 0
# Out:
# 3

# %%
ls=[1,2,3]
3 in ls
20 not in ls
# Out:
# True

# %%
bin(10)
# Out:
# '0b1010'

# %%
hex(10)
# Out:
# '0xa'

# %%
oct(10)
# Out:
# '0o12'

# %%
r=[1,2,3]
s=r
t=[1,2,3]
print(r is s)
print(r is t)
print(r is  not t)
# Out:
# True
# False
# True

# %%
st=('indore','pune','goa','delhi')
st[-4:-1:-1]
# Out:
# ()
